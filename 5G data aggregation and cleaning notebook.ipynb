# %%
#import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os

#use indexing to pick the import driving files from Amazon Prime, Download and Netflix- subfolders of 5G-production-dataset
drive_1 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Amazon_Prime\Driving\animated-AdventureTime')[1:8]
drive_2 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Amazon_Prime\Driving\Season3-TheExpanse')[:]
drive_3 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Download\Driving')[:]
drive_4 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Driving\animated-RickandMorty')[:]
drive_5 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Driving\Season3-StrangerThings')[:]
drive_6 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Driving\Season3-StrangerThings')[:]

# %%
#use indexing to pick the import static files from Amazon Prime, Download and Netflix- subfolders of 5G-production-dataset
static_1 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Amazon_Prime\Static\animated-Ninjago')[:]
static_2 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Amazon_Prime\Static\Season3-TheExpanse')[:]
static_3 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Download\Static')[:]
static_4 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Static\animated-RickandMorty')[:]
static_5 = os.listdir(r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Static\Season3-StrangerThings')[:]

# %%
# def path_file_combiner(path, path_locator_file):
#     import warnings
#     warnings.filterwarnings('ignore')
#     join_initiator= pd.DataFrame() #create empty dataframe to enable joining the different data
#     for file in path_locator_file:     #loop
#         df = pd.read_csv(path +'/'+file, error_bad_lines=False)
#         combined = pd.concat([df,join_initiator]) #join each of the final to each other
#     return combined

# %%
import warnings
warnings.filterwarnings('ignore')

path = r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Amazon_Prime\Driving\animated-AdventureTime' #the path our loop will look at
combine_drive_1 = pd.DataFrame() #create empty dataframe to enable joining the different data
for file in drive_1:
    df = pd.read_csv(path +'/'+file, error_bad_lines=False)
    combine_drive_1 = pd.concat([df,combine_drive_1]) #join each of the final to each other

    
    
path = r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Amazon_Prime\Driving\Season3-TheExpanse' #the path our loop will look at
combine_drive_2= pd.DataFrame() #create empty dataframe to enable joining the different data
for file in drive_2:     #loop
    df = pd.read_csv(path +'/'+file, error_bad_lines=False)
    combine_drive_2 = pd.concat([df,combine_drive_2]) #join each of the final to each other
    
    
    
path = r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Download\Driving' #the path our loop will look at
combine_drive_3= pd.DataFrame() #create empty dataframe to enable joining the different data
for file in drive_3:     #loop
    df = pd.read_csv(path +'/'+file, error_bad_lines=False)
    combine_drive_3 = pd.concat([df,combine_drive_3]) #join each of the final to each other
    
    
    
path = r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Driving\animated-RickandMorty' #the path our loop will look at
combine_drive_4= pd.DataFrame() #create empty dataframe to enable joining the different data
for file in drive_4:     #loop
    df = pd.read_csv(path +'/'+file, error_bad_lines=False)
    combine_drive_3 = pd.concat([df,combine_drive_4]) #join each of the final to each other
    
    
path = r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Driving\Season3-StrangerThings' #the path our loop will look at
combine_drive_5= pd.DataFrame() #create empty dataframe to enable joining the different data
for file in drive_5:     #loop
    df = pd.read_csv(path +'/'+file, error_bad_lines=False)
    combine_drive_3 = pd.concat([df,combine_drive_5]) #join each of the final to each other

    
    
path = r'C:\Users\Ngwu Nneamaka\Desktop\DS\reginald project\5G-production-dataset\Netflix\Driving\Season3-StrangerThings' #the path our loop will look at
combine_drive_6= pd.DataFrame() #create empty dataframe to enable joining the different data
for file in drive_6:     #loop
    df = pd.read_csv(path +'/'+file, error_bad_lines=False)
    combine_drive_3 = pd.concat([df,combine_drive_6]) #join each of the final to each other
# Out:
# b'Skipping line 4: expected 1 fields, saw 2\nSkipping line 5: expected 1 fields, saw 2\nSkipping line 6: expected 1 fields, saw 2\nSkipping line 7: expected 1 fields, saw 2\nSkipping line 8: expected 1 fields, saw 2\nSkipping line 10: expected 1 fields, saw 2\nSkipping line 11: expected 1 fields, saw 2\nSkipping line 12: expected 1 fields, saw 2\nSkipping line 13: expected 1 fields, saw 2\nSkipping line 14: expected 1 fields, saw 2\nSkipping line 15: expected 1 fields, saw 2\nSkipping line 16: expected 1 fields, saw 2\nSkipping line 17: expected 1 fields, saw 3\nSkipping line 18: expected 1 fields, saw 2\nSkipping line 19: expected 1 fields, saw 2\nSkipping line 20: expected 1 fields, saw 2\nSkipping line 21: expected 1 fields, saw 2\nSkipping line 22: expected 1 fields, saw 2\nSkipping line 25: expected 1 fields, saw 2\nSkipping line 27: expected 1 fields, saw 2\nSkipping line 28: expected 1 fields, saw 2\nSkipping line 29: expected 1 fields, saw 2\nSkipping line 30: expected 1 fiel
# ...

# %%
complete_static = pd.read_excel('merged_driving.xlsx')
complete_driving = pd.read_excel('merged_static.xlsx')

# %%
complete_driving.drop('Source.Name', inplace=True, axis=1)
complete_static.drop('Source.Name', inplace=True, axis=1)
complete_driving.drop('Timestamp', inplace=True, axis=1)
complete_static.drop('Timestamp', inplace=True, axis=1)

# %%
complete_driving['Speed'].unique()
# Out:
# array([ 0, 23, 13,  1, 15,  5, 14, 34, 44, 33, 28, 59, 68, 73, 77, 79, 78,
#        80, 81, 75, 74, 76, 82, 50, 22, 35, 46, 55, 67, 72, 83, 84, 85, 86,
#        87, 89, 91, 90, 64, 25, 24, 31, 19, 12,  2,  3], dtype=int64)

# %%
print(complete_driving['NetworkMode'].value_counts())
print(complete_static['NetworkMode'].value_counts())
# Out:
# 5G       78148
# LTE       4520
# HSPA+     2430
# HSUPA       38
# UMTS        30
# Name: NetworkMode, dtype: int64
# 5G       58255
# LTE      30692
# HSPA+    13450
# UMTS       462
# HSUPA      432
# HSDPA      163
# GPRS        78
# EDGE        13
# Name: NetworkMode, dtype: int64

# %%
df_driving_5g = complete_driving.loc[complete_driving['NetworkMode'] == '5G']
df_static_5g = complete_static.loc[complete_static['NetworkMode'] == '5G']

# %%
df_driving_5g.to_csv('5g_drive.csv', index=False)
df_static_5g.to_csv('5g_static.csv', index=False)

# %%
driving = pd.read_csv('5g_drive.csv')
static = pd.read_csv('5g_static.csv')
# Out:
# C:\Users\Ngwu Nneamaka\AppData\Local\Temp\ipykernel_3364\506874231.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   driving = pd.read_csv('5g_drive.csv')

# %%
driving.head()
# Out:
#    Longitude   Latitude  Speed Operatorname  CellID NetworkMode  RSRP  RSRQ  \
# 0  -8.394860  51.886241      0            B      11          5G   -97 -12.0
# 1  -8.394860  51.886241      0            B      11          5G   -94 -13.0
# 2  -8.392723  51.886788      0            B      11          5G   -94 -13.0
# 3  -8.392723  51.886788      0            B      11          5G   -94 -13.0
# 4  -8.392723  51.886788      0            B      11          5G   -96 -13.0
#
#     SNR   CQI  ... PINGMIN  PINGMAX  PINGSTDEV PINGLOSS CELLHEX NODEHEX  \
# 0  10.0  13.0  ...       -        -          -        -       B    A4DF
# 1   8.0  11.0  ...       -        -          -        -       B    A4DF
# 2   8.0  11.0  ...       -        -          -        -       B    A4DF
# 3   8.0  11.0  ...       -        -          -        -       B    A4DF
# 4   4.0  11.0  ...       -        -          -        -       B    A4DF
#
#   LACHEX RAWCELLID NRxRSRP NRxRSRQ
# 0   9CBA  10805003  -103.0   -14.0
# ...

# %%
static.head()
# Out:
#    Longitude   Latitude  Speed Operatorname  CellID NetworkMode  RSRP  RSRQ  \
# 0  -8.491023  51.895347     31            B      13          5G   -98 -15.0
# 1  -8.491023  51.895347     31            B      13          5G   -98 -15.0
# 2  -8.491023  51.895347     31            B      13          5G   -94 -15.0
# 3  -8.491023  51.895347     31            B      13          5G   -94 -15.0
# 4  -8.491023  51.895347     31            B      13          5G   -91 -13.0
#
#    SNR   CQI  ... PINGMIN  PINGMAX  PINGSTDEV PINGLOSS CELLHEX NODEHEX LACHEX  \
# 0  0.0  12.0  ...       -        -          -        -     NaN    A992   9CBA
# 1  0.0  10.0  ...       -        -          -        -     NaN    A992   9CBA
# 2  0.0  10.0  ...       -        -          -        -     NaN    A992   9CBA
# 3  0.0  12.0  ...       -        -          -        -     NaN    A992   9CBA
# 4  3.0  14.0  ...       -        -          -        -     NaN    A992   9CBA
#
#   RAWCELLID NRxRSRP  NRxRSRQ
# ...

# %%
static.replace(to_replace = '-', value = None, inplace = True)
driving.replace(to_replace = '-', value = None, inplace = True)

# %%
static.describe()
# Out:
#           Longitude      Latitude         Speed        CellID          RSRP  \
# count  58255.000000  58255.000000  58255.000000  58255.000000  58255.000000
# mean      -8.432615     51.910567     29.560621     12.129688    -85.918531
# std        0.040977      0.018274     18.006930      0.825230     11.496462
# min       -8.571555     51.872271      0.000000     10.000000   -120.000000
# 25%       -8.473895     51.896812     17.000000     11.000000    -95.000000
# 50%       -8.410408     51.905931     29.000000     12.000000    -86.000000
# 75%       -8.395742     51.929125     41.000000     13.000000    -78.000000
# max       -8.353637     51.955647    100.000000     14.000000    -49.000000
#
#                RSRQ           SNR           CQI     DL_bitrate    UL_bitrate  \
# count  58105.000000  58255.000000  58254.000000   58255.000000  58255.000000
# mean     -12.017090      4.726393     11.620987   11653.124865     46.163282
# ...

# %%
driving.describe()
# Out:
#           Longitude      Latitude         Speed        CellID          RSRP  \
# count  78148.000000  78148.000000  78148.000000  78148.000000  78148.000000
# mean      -8.416134     51.889575      0.613592     11.219225    -96.624469
# std        0.038040      0.005940      4.021801      0.624796      6.781409
# min       -8.483621     51.884203      0.000000     11.000000   -124.000000
# 25%       -8.395336     51.886139      0.000000     11.000000   -101.000000
# 50%       -8.394681     51.886188      0.000000     11.000000    -99.000000
# 75%       -8.394628     51.887334      0.000000     11.000000    -95.000000
# max       -8.353211     51.907512     89.000000     13.000000    -52.000000
#
#                RSRQ           SNR           CQI     DL_bitrate    UL_bitrate  \
# count  78138.000000  78148.000000  78148.000000   78148.000000  78148.000000
# mean     -12.968325      1.312957     11.206800   15260.945155     53.996315
# ...

# %%
driving['RSRQ'].fillna(driving['RSRQ'].mean(), inplace=True)
driving['NRxRSRP'].fillna(driving['NRxRSRP'].mean(), inplace=True)
driving['NRxRSRQ'].fillna(driving['NRxRSRQ'].mean(), inplace=True)

# %%
static['RSRQ'].fillna(static['RSRQ'].mean(), inplace=True)

# %%
static['NRxRSRQ'] = pd.to_numeric(static['NRxRSRQ'], errors='coerce')

# %%
static['NRxRSRP'] = pd.to_numeric(static['NRxRSRP'], errors='coerce')

# %%
static['NRxRSRQ'].fillna(static['NRxRSRQ'].mean(), inplace=True)
static['NRxRSRP'].fillna(static['NRxRSRP'].mean(), inplace=True)

# %%
static.isnull().sum()
# Out:
# Longitude           0
# Latitude            0
# Speed               0
# Operatorname        0
# CellID              0
# NetworkMode         0
# RSRP                0
# RSRQ                0
# SNR                 0
# CQI                 1
# RSSI             5010
# DL_bitrate          0
# UL_bitrate          0
# State               0
# PINGAVG         57213
# PINGMIN         57213
# PINGMAX         57213
# PINGSTDEV       57213
# PINGLOSS        57207
# CELLHEX         58255
# NODEHEX             0
# LACHEX              0
# RAWCELLID           0
# NRxRSRP             0
# NRxRSRQ             0
# dtype: int64

# %%
driving.isnull().sum()
# Out:
# Longitude           0
# Latitude            0
# Speed               0
# Operatorname        0
# CellID              0
# NetworkMode         0
# RSRP                0
# RSRQ                0
# SNR                 0
# CQI                 0
# RSSI            25953
# DL_bitrate          0
# UL_bitrate          0
# State               0
# PINGAVG         76926
# PINGMIN         76926
# PINGMAX         76926
# PINGSTDEV       76926
# PINGLOSS        76910
# CELLHEX             0
# NODEHEX             0
# LACHEX              0
# RAWCELLID           0
# NRxRSRP             0
# NRxRSRQ             0
# dtype: int64

# %%
driving['CELLHEX'].unique()
# Out:
# array(['B', 'D', 'C'], dtype=object)

# %%
static['CELLHEX'].unique()
# Out:
# array([nan])

# %%
static.nunique()
# Out:
# Longitude        3261
# Latitude         3201
# Speed             101
# Operatorname        3
# CellID              5
# NetworkMode         1
# RSRP               72
# RSRQ               24
# SNR                54
# CQI                16
# RSSI               72
# DL_bitrate      13388
# UL_bitrate        853
# State               3
# PINGAVG            69
# PINGMIN            37
# PINGMAX            93
# PINGSTDEV          57
# PINGLOSS            6
# CELLHEX             0
# NODEHEX            31
# LACHEX              3
# RAWCELLID          67
# NRxRSRP            93
# NRxRSRQ            55
# dtype: int64

# %%
driving.nunique()
# Out:
# Longitude          85
# Latitude           84
# Speed              39
# Operatorname        3
# CellID              3
# NetworkMode         1
# RSRP               55
# RSRQ               18
# SNR                43
# CQI                16
# RSSI               61
# DL_bitrate      20365
# UL_bitrate       1048
# State               4
# PINGAVG            71
# PINGMIN            49
# PINGMAX            92
# PINGSTDEV          56
# PINGLOSS            6
# CELLHEX             3
# NODEHEX             6
# LACHEX              2
# RAWCELLID           8
# NRxRSRP            60
# NRxRSRQ            43
# dtype: int64

# %%
# View the index number and label for each column
for i, v in enumerate(static.columns):
    print(i, v)
# Out:
# 0 Longitude
# 1 Latitude
# 2 Speed
# 3 Operatorname
# 4 CellID
# 5 NetworkMode
# 6 RSRP
# 7 RSRQ
# 8 SNR
# 9 CQI
# 10 RSSI
# 11 DL_bitrate
# 12 UL_bitrate
# 13 State
# 14 PINGAVG
# 15 PINGMIN
# 16 PINGMAX
# 17 PINGSTDEV
# 18 PINGLOSS
# 19 CELLHEX
# 20 NODEHEX
# 21 LACHEX
# 22 RAWCELLID
# 23 NRxRSRP
# 24 NRxRSRQ

# %%
# View the index number and label for each column
for i, v in enumerate(driving.columns):
    print(i, v)
# Out:
# 0 Longitude
# 1 Latitude
# 2 Speed
# 3 Operatorname
# 4 CellID
# 5 NetworkMode
# 6 RSRP
# 7 RSRQ
# 8 SNR
# 9 CQI
# 10 RSSI
# 11 DL_bitrate
# 12 UL_bitrate
# 13 State
# 14 PINGAVG
# 15 PINGMIN
# 16 PINGMAX
# 17 PINGSTDEV
# 18 PINGLOSS
# 19 CELLHEX
# 20 NODEHEX
# 21 LACHEX
# 22 RAWCELLID
# 23 NRxRSRP
# 24 NRxRSRQ

# %%
static.loc[:,'RSSI':'LACHEX']
# Out:
#        RSSI  DL_bitrate  UL_bitrate State PINGAVG PINGMIN PINGMAX PINGSTDEV  \
# 0      None           0           0     D    None    None    None      None
# 1      None           0           0     I    None    None    None      None
# 2      None           2           4     D    None    None    None      None
# 3       -80           0           0     I    None    None    None      None
# 4       -82           0           0     D    None    None    None      None
# ...     ...         ...         ...   ...     ...     ...     ...       ...
# 58250  -113       12577          83     D    None    None    None      None
# 58251  -113        2873          96     D    None    None    None      None
# 58252  -113        2178         102     D    None    None    None      None
# 58253  -113        2178         102     D    None    None    None      None
# 58254  -113          11           1     D    None    None    None      None
#
#       PINGLOSS  CELLHEX NODEHEX LACHEX
# ...

# %%
driving.loc[:,'RSSI':'LACHEX']
# Out:
#        RSSI  DL_bitrate  UL_bitrate State PINGAVG PINGMIN PINGMAX PINGSTDEV  \
# 0      None         141          44     D    None    None    None      None
# 1      None           0           7     D    None    None    None      None
# 2      None           0           7     D    None    None    None      None
# 3      None          53           8     D    None    None    None      None
# 4      None           0           0     I    None    None    None      None
# ...     ...         ...         ...   ...     ...     ...     ...       ...
# 78143  -105           0           0     D    70.0    64.0    76.0       5.0
# 78144  -105       84590         378     D    None    None    None      None
# 78145  -105      276708         357     D    None    None    None      None
# 78146  -105      276724         193     D    None    None    None      None
# 78147  -105       40469          43     D    None    None    None      None
#
#       PINGLOSS CELLHEX NODEHEX LACHEX
# ...

# %%
sum(static.duplicated())
# Out:
# 3794

# %%
sum(driving.duplicated())
# Out:
# 13856

# %%
static.drop_duplicates(inplace=True)
driving.drop_duplicates(inplace=True)

# %%
static.shape
# Out:
# (54461, 25)

# %%
driving.shape
# Out:
# (64292, 25)

# %%
driving.hist(figsize= (12,10));

# %%
static.to_csv('static_5G_data.csv')
driving.to_csv('driving_5G_data.csv')
